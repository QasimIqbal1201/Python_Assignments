# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Stores data.csv')  #Loading the data

# %%
df
# Out:
#       invoice_no      invoice_date customer_id  gender  age         category  \
# 0        I138884   10/30/2016 9:58     C241288  Female   28         Clothing
# 1        I317333   10/30/2016 9:58     C111565    Male   21            Shoes
# 2        I127801   10/30/2016 9:58     C266599    Male   20         Clothing
# 3        I173702   10/30/2016 9:58     C988172  Female   66            Shoes
# 4        I337046   10/30/2016 9:59     C189076  Female   53            Books
# ...          ...               ...         ...     ...  ...              ...
# 99452    I219422  11/15/2016 12:43     C441542  Female   45         Souvenir
# 99453    I325143  11/15/2016 12:43     C569580    Male   27  Food & Beverage
# 99454    I824010  11/15/2016 12:44     C103292    Male   63  Food & Beverage
# 99455    I702964  11/15/2016 12:44     C800631    Male   56       Technology
# 99456    I232867  11/15/2016 12:44     C273973  Female   36         Souvenir
#
# ...

# %%
#QUESTION 01 Check missing values and duplicate record

df.isnull().sum()
# Out:
# invoice_no                0
# invoice_date              0
# customer_id               0
# gender                    0
# age                       0
# category                  0
# quantity                  0
# selling_price_per_unit    0
# cost_price_per_unit       0
# payment_method            0
# region                    0
# state                     0
# shopping_mall             0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99452    False
# 99453    False
# 99454    False
# 99455    False
# 99456    False
# Length: 99457, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#QUESTION 02 Add column name 'Total Sales'
df['Total Sales'] = df['quantity']  * df['selling_price_per_unit']

# %%
print(df.head())
# Out:
#   invoice_no     invoice_date customer_id  gender  age  category  quantity  \
# 0    I138884  10/30/2016 9:58     C241288  Female   28  Clothing         5
# 1    I317333  10/30/2016 9:58     C111565    Male   21     Shoes         3
# 2    I127801  10/30/2016 9:58     C266599    Male   20  Clothing         1
# 3    I173702  10/30/2016 9:58     C988172  Female   66     Shoes         5
# 4    I337046  10/30/2016 9:59     C189076  Female   53     Books         4
#
#    selling_price_per_unit  cost_price_per_unit payment_method region  \
# 0                 1500.40             1425.380    Credit Card  South
# 1                 1800.51             1620.459     Debit Card  South
# 2                  300.08              295.060           Cash   West
# 3                 3000.85             2900.765    Credit Card  South
# 4                   60.60               45.450           Cash  South
#
#         state   shopping_mall  Total Sales
# 0    Kentucky          Kanyon            0
# ...

# %%
# QUESTION 03 How many customers have age more than 60?

# %%
(df['age']> 60).sum()
# Out:
# 17169

# %%
#QUESTION 04 How many unique customer_id entries are there? Do any customers make multiple purchases?
df.customer_id.unique()
# Out:
# array(['C241288', 'C111565', 'C266599', ..., 'C103292', 'C800631',
#        'C273973'], dtype=object)

# %%
df.customer_id.nunique()
# Out:
# 99457

# %%
df.customer_id.value_counts()
# Out:
# C241288    1
# C116138    1
# C382765    1
# C285074    1
# C405356    1
#           ..
# C220083    1
# C286933    1
# C301304    1
# C214184    1
# C273973    1
# Name: customer_id, Length: 99457, dtype: int64

# %%
#QUESTION 05 Are there more male or female customers, Show in Pie Chart?

# %%
df.gender.value_counts().plot(kind = 'pie')
plt.show()

# %%
#QUESTION 06  Which category is least popular among customers?

# %%
df.category.value_counts().tail(5)
# Out:
# Toys          10087
# Shoes         10034
# Souvenir       4999
# Technology     4996
# Books          4981
# Name: category, dtype: int64

# %%
df.category.value_counts().nsmallest(1)
# Out:
# Books    4981
# Name: category, dtype: int64

# %%
#QUESTION 07 Which category has the highest sales volume?

# %%
df['Total sales'] = df['quantity']*df['selling_price_per_unit']
df
# Out:
#       invoice_no      invoice_date customer_id  gender  age         category  \
# 0        I138884   10/30/2016 9:58     C241288  Female   28         Clothing
# 1        I317333   10/30/2016 9:58     C111565    Male   21            Shoes
# 2        I127801   10/30/2016 9:58     C266599    Male   20         Clothing
# 3        I173702   10/30/2016 9:58     C988172  Female   66            Shoes
# 4        I337046   10/30/2016 9:59     C189076  Female   53            Books
# ...          ...               ...         ...     ...  ...              ...
# 99452    I219422  11/15/2016 12:43     C441542  Female   45         Souvenir
# 99453    I325143  11/15/2016 12:43     C569580    Male   27  Food & Beverage
# 99454    I824010  11/15/2016 12:44     C103292    Male   63  Food & Beverage
# 99455    I702964  11/15/2016 12:44     C800631    Male   56       Technology
# 99456    I232867  11/15/2016 12:44     C273973  Female   36         Souvenir
#
# ...

# %%
df.groupby('category')['Total sales'].sum().nlargest(1)
# Out:
# category
# Clothing    1.140145e+08
# Name: Total sales, dtype: float64

# %%
#QUESTION 08 Add column name 'Total Profit'
df['Total Profit'] = df['Total sales'] - (df['quantity']*df['cost_price_per_unit'])
df
# Out:
#       invoice_no      invoice_date customer_id  gender  age         category  \
# 0        I138884   10/30/2016 9:58     C241288  Female   28         Clothing
# 1        I317333   10/30/2016 9:58     C111565    Male   21            Shoes
# 2        I127801   10/30/2016 9:58     C266599    Male   20         Clothing
# 3        I173702   10/30/2016 9:58     C988172  Female   66            Shoes
# 4        I337046   10/30/2016 9:59     C189076  Female   53            Books
# ...          ...               ...         ...     ...  ...              ...
# 99452    I219422  11/15/2016 12:43     C441542  Female   45         Souvenir
# 99453    I325143  11/15/2016 12:43     C569580    Male   27  Food & Beverage
# 99454    I824010  11/15/2016 12:44     C103292    Male   63  Food & Beverage
# 99455    I702964  11/15/2016 12:44     C800631    Male   56       Technology
# 99456    I232867  11/15/2016 12:44     C273973  Female   36         Souvenir
#
# ...

# %%
#QUESTION 09 Display the top 10 invoices with the highest quantities sold?

# %%
df.groupby('invoice_no')['quantity'].sum().nlargest(10)
# Out:
# invoice_no
# I283443    15
# I282789    12
# I293215    12
# I115679    11
# I160221    10
# I207205    10
# I353272    10
# I286193     9
# I139207     8
# I215578     8
# Name: quantity, dtype: int64

# %%
#QUESTION 10 Which payment method is most commonly used?

# %%
df.payment_method.value_counts().nlargest(1)
# Out:
# Cash    44447
# Name: payment_method, dtype: int64

# %%
#QUESTION 11 Total Sales with respect to region?

# %%
df.groupby('region')['Total Sales'].sum()
# Out:
# region
# Central    58803471.74
# East       72280660.57
# South      40655491.64
# West       79825624.03
# Name: Total Sales, dtype: float64

# %%
#QUESTION 12 Sort Malls with average sales higher to lower
df.groupby('shopping_mall')['Total sales'].mean().sort_values(ascending = False)
# Out:
# shopping_mall
# Zorlu Center        2573.248351
# Kanyon              2550.618396
# Mall of Istanbul    2543.276766
# Viaport Outlet      2523.835118
# Istinye Park        2523.186677
# Metropol AVM        2497.777108
# Metrocity           2485.030133
# Name: Total sales, dtype: float64

# %%
#QUESTION 13  Sort categories with the highest profit margins display in bar plot?
#Profit Margin=(Total Sales/Total Profit)×100

df['Profit margin'] = (df['Total Sales'] / df['Total Profit']) * 100
df.head(4)
# Out:
#   invoice_no     invoice_date customer_id  gender  age  category  quantity  \
# 0    I138884  10/30/2016 9:58     C241288  Female   28  Clothing         5
# 1    I317333  10/30/2016 9:58     C111565    Male   21     Shoes         3
# 2    I127801  10/30/2016 9:58     C266599    Male   20  Clothing         1
# 3    I173702  10/30/2016 9:58     C988172  Female   66     Shoes         5
#
#    selling_price_per_unit  cost_price_per_unit payment_method region  \
# 0                 1500.40             1425.380    Credit Card  South
# 1                 1800.51             1620.459     Debit Card  South
# 2                  300.08              295.060           Cash   West
# 3                 3000.85             2900.765    Credit Card  South
#
#         state   shopping_mall  Total Sales  Total sales  Total Profit  \
# 0    Kentucky          Kanyon      7502.00      7502.00       375.100
# 1    Kentucky  Viaport Outlet      5401.53      5401.53       540.153
# ...

# %%
df.groupby('category')['Profit margin'].mean().sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <Axes: xlabel='category'>

# %%
#QUESTION 14 What is the total number of transactions per region for each payment method?

# %%
df.groupby(['region', 'payment_method']).size()
# Out:
# region   payment_method
# Central  Cash              10319
#          Credit Card        8140
#          Debit Card         4640
# East     Cash              12738
#          Credit Card        9817
#          Debit Card         5751
# South    Cash               7227
#          Credit Card        5698
#          Debit Card         3284
# West     Cash              14163
#          Credit Card       11276
#          Debit Card         6404
# dtype: int64

# %%
#QUESTION 15 How do sales in different categories compare between males and females
df.groupby(['category', 'gender'])['Total Sales'].sum()
# Out:
# category         gender
# Books            Female      489420.75
#                  Male        345238.20
# Clothing         Female    68260097.84
#                  Male      45754397.92
# Cosmetics        Female     4068073.66
#                  Male       2728611.28
# Food & Beverage  Female      505322.60
#                  Male        344233.37
# Shoes            Female    39425167.30
#                  Male      27128284.17
# Souvenir         Female      382867.20
#                  Male        252957.45
# Technology       Female    34669950.00
#                  Male      23230200.00
# Toys             Female     2416046.08
#                  Male       1564380.16
# Name: Total Sales, dtype: float64
